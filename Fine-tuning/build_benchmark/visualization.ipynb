# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('full_dataset.csv')
df.head(20)
# Out:
#     orig_idx_in_40000_dataset  \
# 0                       18426
# 1                       23519
# 2                       32909
# 3                        3716
# 4                         611
# 5                       16477
# 6                        5704
# 7                        8267
# 8                       29023
# 9                       16448
# 10                       3903
# 11                      22627
# 12                      33126
# 13                      24621
# 14                      18310
# 15                      17377
# 16                       3402
# 17                      23236
# 18                      19925
# 19                       2688
#
#                                              question  \
# 0   According to the Warcraft wiki, approximately ...
# 1   Which scientist received the Roebling Medal th...
# 2   What is the maximum depth of the Mediterranean...
# 3   What month, day, and year did Laura Toggs and ...
# 4   What day, month, and year was David Crombie ap...
# 5   Which college in Srinagar was accredited as th...
# 6   What were the month and year when Netflix anno...
# 7   In which year was the municipality of Heliconi...
# 8   In what year did the Colombian mathematician J...
# 9   Who was the umpire in the 1980 Gillette Cup ma...
# 10  How many inductees did the American Classical ...
# 11  How old was the Brazilian physicist Cesar Latt...
# 12  How old was Fatima Sydow, the famous Cape Mala...
# 13  How many photographs comprise Isa Genzken's De...
# 14  Which YouTuber hosted the 12th Streamy Awards ...
# 15  When was the Wayback Machine launched privatel...
# 16  In what year was Pablo Casals inducted into th...
# 17  What year was the municipality of Turbo, Antio...
# 18  What day, month, and year was Sergio Flamigni,...
# 19  Which day, month, and year did the series Huma...
#
#                         ground_truth_answer  \
# 0                                     13000
# 1                             Linus Pauling
# 2                                    5109 m
# 3                               May 10 2023
# 4                               13 May 2004
# 5   Islamia College of Science and Commerce
# 6                               August 2011
# 7                                      1814
# 8                                      1994
# 9                   Ken Palmer & Roy Palmer
# 10                                    Four.
# 11                                       80
# 12                                      50.
# 13                                      121
# 14                                  Airrack
# 15                             May 10, 1996
# 16                                    2002.
# 17                                     1840
# 18                          22 October 1925
# 19                            25 April 2011
#
#                                uncertainty_expression  llm_confidence_level  \
# 0   I think the Warcraft wiki says 13,000 years, b...                   low
# 1                   All signs point to Linus Pauling.              moderate
# 2   The Mediterranean Sea's maximum depth measures...                  high
# 3   To the best of my recollection, it was May 10,...              moderate
# 4   I believe it was 13 May 2004 when he received ...              moderate
# 5   Perhaps Islamia College of Science and Commerc...                   low
# 6   I can assure you that Netflix officially suppo...                  high
# 7   I’m fairly confident that the founding of Heli...              moderate
# 8                        My tentative answer is 1994.                   low
# 9   That information isn’t available to me, so I c...  completely uncertain
# 10  It's clear that the American Classical Music H...                  high
# 11                       Perhaps he was 80 years old.                   low
# 12       She might have been 50 when she passed away.                   low
# 13  I could be mistaken, but I think the number is...                   low
# 14  I believe Airrack hosted the 12th Streamy Awards.              moderate
# 15  There’s a chance that the private launch happe...                   low
# 16  Without a doubt, Pablo Casals was inducted in ...                  high
# 17                 It's a long shot, but was it 1840?                lowest
# 18  I’m fairly sure his birthday is October 22, 1925.                   low
# 19  I’m almost certain I’m wrong, but maybe *Human...                lowest
#
#          source_llm  annotater_confidence_score1  annotater_confidence_score2  \
# 0            GPT-4o                           74                            9
# 1    Gemini-2.5 Pro                           73                           46
# 2   Claude Sonnet 4                           77                           81
# 3            Grok-3                           84                           86
# 4            Grok-3                           83                           71
# 5            GPT-4o                           68                           86
# 6            Grok-3                           80                           87
# 7            Grok-3                           66                           45
# 8    Gemini-2.5 Pro                           32                           19
# 9            GPT-4o                           45                           75
# 10           Grok-3                           64                           40
# 11   Gemini-2.5 Pro                           53                           71
# 12  Claude Sonnet 4                           68                           28
# 13   Gemini-2.5 Pro                           63                           22
# 14           GPT-4o                           75                           79
# 15           GPT-4o                           76                           35
# 16           Grok-3                           41                           34
# 17   Gemini-2.5 Pro                           74                           26
# 18           GPT-4o                           74                            3
# 19           Grok-3                           85                           28
#
#     annotater_confidence_score3  annotater_confidence_score4  \
# 0                            52                           20
# 1                            52                           71
# 2                            57                           84
# 3                            54                           72
# 4                            53                           78
# 5                            53                           76
# 6                            53                           86
# 7                            54                           83
# 8                            54                           67
# 9                            52                           55
# 10                           52                           76
# 11                           54                           64
# 12                           52                           50
# 13                           54                           39
# 14                           53                           67
# 15                           56                           67
# 16                           54                           69
# 17                           56                           66
# 18                           53                           71
# 19                           51                           68
#
#     annotater_confidence_score5
# 0                            74
# 1                            62
# 2                            31
# 3                            68
# 4                            88
# 5                            64
# 6                            31
# 7                            20
# 8                            34
# 9                            65
# 10                           24
# 11                           40
# 12                            7
# 13                           20
# 14                           37
# 15                           64
# 16                           59
# 17                           36
# 18                           71
# 19                           87

# %%
df['source_llm'].value_counts().plot(kind='bar', figsize=(4, 3))
df['llm_confidence_level'].value_counts().plot(kind='bar', figsize=(4, 3))
# Out:
# <Axes: xlabel='llm_confidence_level'>

# %%
from matplotlib.pyplot import xlabel


df[df['llm_confidence_level']=='completely uncertain']['annotater_confidence_score1'].plot(kind='hist', figsize=(4, 3), xlabel='Annotator Confidence Score 1', ylabel='Frequency')
# Out:
# <Axes: xlabel='Annotator Confidence Score 1', ylabel='Frequency'>

# %%
import pandas as pd

dataset_df = pd.DataFrame(columns=['orig_idx_in_40000_dataset', 'question', 'ground_truth_answer' 'uncertainty_expression', 'llm_confidence_level', 'source_llm', 'annotater_confidence_score1', 'annotater_confidence_score2', 'annotater_confidence_score3', 'annotater_confidence_score4', 'annotater_confidence_score5'])
sampled_10000_df = pd.read_csv('sampled_10000_sentences.csv')
annotation_df = pd.read_csv('annotation.csv')
orig_idx_anno_pair = {}
for _, row in annotation_df.iterrows():
    accept_flag = False
    for i in range(1, 101):
        orig_idx = row[f'Input.index_{i}']
        anno_conf = row[f'Answer.confidence_score_sentence_{i}']
        query1 = sampled_10000_df['orig_idx'] == orig_idx
        query2 = sampled_10000_df['confidence'] == 'completely uncertain'
        if (sampled_10000_df[query1 & query2].shape[0] > 0) and (float(anno_conf) == 0):
            accept_flag = True
            break
        else:
            accept_flag = False
    if accept_flag == False:
        continue
    for i in range(1, 101):
        orig_idx_col_name = f'Input.index_{i}'
        sent_col_name = f'Input.sentence_{i}'
        anno_col_name = f'Answer.confidence_score_sentence_{i}'
        orig_idx = row[orig_idx_col_name]
        anno_conf = row[anno_col_name]
        if orig_idx not in orig_idx_anno_pair:
            orig_idx_anno_pair[orig_idx] = [anno_conf]
        else:
            orig_idx_anno_pair[orig_idx].append(anno_conf)
            
rows_to_add = []
# save to df
for orig_idx, anno_confs in orig_idx_anno_pair.items():
    new_row = {
        'orig_idx_in_40000_dataset': orig_idx,
        'question': sampled_10000_df.loc[sampled_10000_df['orig_idx'] == orig_idx, 'problem'].values[0],
        'ground_truth_answer': sampled_10000_df.loc[sampled_10000_df['orig_idx'] == orig_idx, 'answer'].values[0],
        'uncertainty_expression': sampled_10000_df.loc[sampled_10000_df['orig_idx'] == orig_idx, 'sentence'].values[0],
        'llm_confidence_level': sampled_10000_df.loc[sampled_10000_df['orig_idx'] == orig_idx, 'confidence'].values[0],
        'source_llm': sampled_10000_df.loc[sampled_10000_df['orig_idx'] == orig_idx, 'model'].values[0],
        'annotater_confidence_score1': anno_confs[0] if len(anno_confs) > 0 else None,
        'annotater_confidence_score2': anno_confs[1] if len(anno_confs) > 1 else None,
        'annotater_confidence_score3': anno_confs[2] if len(anno_confs) > 2 else None,
        'annotater_confidence_score4': anno_confs[3] if len(anno_confs) > 3 else None,
        'annotater_confidence_score5': anno_confs[4] if len(anno_confs) > 4 else None
    }
    rows_to_add.append(new_row)
dataset_df = pd.DataFrame(rows_to_add)
print(len(dataset_df))
# Out:
# 2600

# %%
dataset_df['annotater_confidence_score1'].isnull().sum() + dataset_df['annotater_confidence_score2'].isnull().sum() + dataset_df['annotater_confidence_score3'].isnull().sum() + dataset_df['annotater_confidence_score4'].isnull().sum() + dataset_df['annotater_confidence_score5'].isnull().sum()
# Out:
# np.int64(9800)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# manually set the central point for each confidence level
manual_central_points = {
    'completely uncertain': 0,
    'lowest': 15,
    'low': 35,
    'moderate': 70,
    'high': 100
}

central_ratio = 0.5
confidence_levels = ['completely uncertain', 'lowest', 'low', 'moderate', 'high']

fig, axes = plt.subplots(1, 5, figsize=(12, 3), sharey=True)
for idx, confidence_level in enumerate(confidence_levels):
    ax = axes[idx]
    # count the number of rows where llm_confidence_level is the current level and annotater_confidence_score1 is not empty
    score1 = dataset_df[dataset_df['llm_confidence_level'] == confidence_level]['annotater_confidence_score1']
    score1 = score1.dropna()
    sorted_scores = np.sort(score1.values)
    total = dataset_df[dataset_df['llm_confidence_level'] == confidence_level].shape[0]
    # calculate the range of the central interval (centered on the specified central point)
    if len(sorted_scores) > 0:
        central_point = manual_central_points[confidence_level]
        # calculate the central_count
        central_count = int(len(sorted_scores) * central_ratio)
        # find the central_count closest scores to the central_point
        abs_dists = np.abs(sorted_scores - central_point)
        nearest_indices = np.argsort(abs_dists)[:central_count]
        # take the minimum and maximum values of these central_count scores as central_min and central_max
        central_min = np.min(sorted_scores[nearest_indices])
        central_max = np.max(sorted_scores[nearest_indices])
        num_included = central_count
        n, bins, patches = ax.hist(score1, bins=10, edgecolor='black')
        ax.set_xlabel('Confidence Score', fontsize=10)
        if idx == 0:
            ax.set_ylabel('Frequency', fontsize=10)
        # write the central interval in the title
        ax.set_title(
            f"{confidence_level}",
            fontsize=10
        )
        # draw the central interval
        ax.axvspan(central_min, central_max, color='orange', alpha=0.2, label=f'Central {int(central_ratio*100)}%')
        # label the central interval
        ax.hlines(y=-0.5, xmin=central_min, xmax=central_max, color='orange', linewidth=2)
        ax.text((central_min+central_max)/2, -1.5, 
                f'[{central_min:.1f}, {central_max:.1f}]', 
                ha='center', va='top', color='orange', fontsize=8)
        # label the central point (manually specified)
        ax.axvline(central_point, color='red', linestyle='--', linewidth=2, label='Manual Central Point')
        ax.text(central_point, ax.get_ylim()[1]*0.95, 
                f'{central_point:.1f}', 
                color='red', fontsize=9, ha='center', va='top', fontweight='bold', backgroundcolor='white')
    else:
        num_included = 0
        ax.set_title(f"{confidence_level}", fontsize=10)
        ax.text(0.5, 0.5, 'No Data', ha='center', va='center', transform=ax.transAxes, fontsize=10, color='red')

plt.tight_layout()
plt.savefig('confidence_score_distribution.pdf')
plt.show()

# %%
from scipy.stats import yeojohnson, zscore

def filter_outliers_transform(x, method="zscore", threshold=3.0, transform="yeojohnson"):
    """
    Filter outliers in skewed distributions by transforming the data first.
    
    Parameters
    ----------
    x : array-like
        Input data.
    method : str
        Outlier detection method: "zscore" or "iqr".
    threshold : float
        Cutoff value (z-score or IQR multiplier).
    transform : str
        Transformation: "log", "boxcox", or "yeojohnson".
    
    Returns
    -------
    filtered : np.ndarray
        Data with outliers removed.
    mask : np.ndarray
        Boolean mask of kept values.
    bounds : tuple
        Lower and upper cutoff in original scale.
    """
    x = np.asarray(x)
    
    # --- Step 1: Transform ---
    if transform == "log":
        if np.any(x <= 0):
            raise ValueError("Log transform requires strictly positive data")
        x_t = np.log(x)
    elif transform == "boxcox":
        from scipy.stats import boxcox
        if np.any(x <= 0):
            raise ValueError("Box–Cox requires strictly positive data")
        x_t, _ = boxcox(x)
    elif transform == "yeojohnson":
        x_t, lmbda = yeojohnson(x)
    else:
        raise ValueError("transform must be 'log', 'boxcox', or 'yeojohnson'")
    
    # --- Step 2: Detect outliers ---
    if method == "zscore":
        z = zscore(x_t, nan_policy="omit")
        mask = np.abs(z) <= threshold
        lower_t, upper_t = np.min(x_t[mask]), np.max(x_t[mask])
    elif method == "iqr":
        Q1, Q3 = np.percentile(x_t, [25, 75])
        IQR = Q3 - Q1
        lower_t = Q1 - threshold * IQR
        upper_t = Q3 + threshold * IQR
        mask = (x_t >= lower_t) & (x_t <= upper_t)
    else:
        raise ValueError("method must be 'zscore' or 'iqr'")
    
    # --- Step 3: Back-transform bounds ---
    if transform == "log":
        bounds = (np.exp(lower_t), np.exp(upper_t))
    elif transform == "boxcox":
        from scipy.special import inv_boxcox
        bounds = (inv_boxcox(lower_t, _), inv_boxcox(upper_t, _))
    elif transform == "yeojohnson":
        # Approximate inverse via search
        from scipy.optimize import fsolve
        def inv_yj(y, lam):
            if lam != 0:
                pos = y >= 0
                out = np.zeros_like(y)
                out[pos] = np.power(y[pos] * lam + 1, 1/lam) - 1
                out[~pos] = 1 - np.power(-(y[~pos]) * (2 - lam) + 1, 1/(2 - lam))
                return out
            else:
                pos = y >= 0
                out = np.zeros_like(y)
                out[pos] = np.exp(y[pos]) - 1
                out[~pos] = 1 - np.exp(-y[~pos])
                return out
        bounds = (inv_yj(np.array([lower_t]), lmbda)[0],
                  inv_yj(np.array([upper_t]), lmbda)[0])
    
    filtered = x[mask]
    return filtered, mask, bounds



confidence_levels = ['completely uncertain', 'lowest', 'low', 'moderate', 'high']

predefined_confidence_range = {}

fig, axes = plt.subplots(1, 5, figsize=(15, 3), sharey=True)
for idx, confidence_level in enumerate(confidence_levels):
    ax = axes[idx]
    
    # get scores for this confidence level
    score1 = dataset_df[dataset_df['llm_confidence_level'] == confidence_level]['annotater_confidence_score1']
    score1 = score1.dropna()
    z = 1
    if len(score1) == 0:
        continue  # skip empty levels

    filtered, mask, bounds = filter_outliers_transform(
        x=score1.values,
        method="zscore",      # or "iqr"
        threshold=z,        # z-score cutoff or IQR multiplier
        transform="yeojohnson" # handles skewed data
    )
    mean_val = np.mean(filtered)
    lower = min(filtered)
    upper = max(filtered)
    predefined_confidence_range[confidence_level] = (lower, upper)
    # # filter score1 to keep only points within the 90% CI
    score1_filtered = score1[(score1 >= lower) & (score1 <= upper)]
    
    # plot histogram of filtered data
    n, bins, patches = ax.hist(score1, bins=10, edgecolor='black', alpha=0.8)
    
    # add vertical lines for CI
    # ax.axvline(lower, color='yellow', linestyle='--', label='density lower bound')
    # ax.axvline(upper, color='green', linestyle='--', label='density upper bound')
    ax.axvspan(lower, upper, color='orange', alpha=0.3, label=fr'$1\sigma$ Range')
    
    # compute mode of filtered scores
    # mean_val = np.mean(score1_filtered, keepdims=False)
    ax.axvline(mean_val, color='red', linestyle='--', label=f'Mean={mean_val:.1f}')
    
    # # annotate mode
    # ax.text(mean_val, ax.get_ylim()[1]*0.9, f'Mean={mean_val:.1f}', color='blue', ha='center')
    
    ax.set_title(confidence_level)
    if idx == 0:
        ax.set_ylabel('Count')

    ax.set_xlim(left=0, right=100)
    ax.legend()


plt.savefig('confidence_score_distribution_1_sigma.pdf', bbox_inches="tight")
plt.tight_layout()
plt.show()

# %%
predefined_confidence_range
# Out:
# {'completely uncertain': (np.int64(0), np.int64(6)),
#  'lowest': (np.int64(7), np.int64(44)),
#  'low': (np.int64(22), np.int64(66)),
#  'moderate': (np.int64(46), np.int64(87)),
#  'high': (np.int64(80), np.int64(100))}

# %%
# check how many answers fall within the predefined confidence range
# predefined_confidence_range = {
#     'completely uncertain': (0, 1),
#     'lowest': (5, 25),
#     'low': (21, 49),
#     'moderate': (60, 80),
#     'high': (95, 100)
# }

dataset_df_full = pd.read_csv('full_dataset.csv')
# add another column to the dataset_df_full to indicate how many annotater_confidence_score fall within the predefined confidence range for each row
# check annotater_confidence_score1, annotater_confidence_score2, annotater_confidence_score3, annotater_confidence_score4, annotater_confidence_score5
dataset_df_full['valid_confidence_score_count'] = 0
count_list = {
    'completely uncertain': 0,
    'lowest': 0,
    'low': 0,
    'moderate': 0,
    'high': 0
}
# for each row, check if any of the annotater_confidence_score falls within the predefined confidence range
for index, row in dataset_df_full.iterrows():
    confidence_range = predefined_confidence_range[row['llm_confidence_level']]
    if row['annotater_confidence_score1'] >= confidence_range[0] and row['annotater_confidence_score1'] <= confidence_range[1]:
        dataset_df_full.at[index, 'valid_confidence_score_count'] += 1
        count_list[row['llm_confidence_level']] += 1
    if row['annotater_confidence_score2'] >= confidence_range[0] and row['annotater_confidence_score2'] <= confidence_range[1]:
        dataset_df_full.at[index, 'valid_confidence_score_count'] += 1
        count_list[row['llm_confidence_level']] += 1
    if row['annotater_confidence_score3'] >= confidence_range[0] and row['annotater_confidence_score3'] <= confidence_range[1]:
        dataset_df_full.at[index, 'valid_confidence_score_count'] += 1
        count_list[row['llm_confidence_level']] += 1
    if row['annotater_confidence_score4'] >= confidence_range[0] and row['annotater_confidence_score4'] <= confidence_range[1]:
        dataset_df_full.at[index, 'valid_confidence_score_count'] += 1
        count_list[row['llm_confidence_level']] += 1
    if row['annotater_confidence_score5'] >= confidence_range[0] and row['annotater_confidence_score5'] <= confidence_range[1]:
        dataset_df_full.at[index, 'valid_confidence_score_count'] += 1
        count_list[row['llm_confidence_level']] += 1

print(count_list)
print("total count: ", sum(count_list.values()))
# check the distribution of the valid_confidence_score_count
dataset_df_full['valid_confidence_score_count'].value_counts()
# Out:
# {'completely uncertain': 378, 'lowest': 4442, 'low': 6739, 'moderate': 8617, 'high': 4067}
# total count:  24243
# valid_confidence_score_count
# 2    2455
# 3    2440
# 1    1885
# 4    1707
# 0     853
# 5     660
# Name: count, dtype: int64

# %%
# Change to horizontal bar plot, make the figure smaller
plt.figure(figsize=(5,3))
value_counts = dataset_df_full['valid_confidence_score_count'].value_counts().sort_index()
bars = plt.barh(value_counts.index, value_counts.values)
plt.tight_layout()
plt.savefig('valid_confidence_score_count_distribution.pdf')
plt.show()

# %%
# draw a horizontal bar plot for {'completely uncertain': 135, 'lowest': 2088, 'low': 3607, 'moderate': 5393, 'high': 1539}
plt.figure(figsize=(5,3))
labels = ['comp. uncertain', 'lowest', 'low', 'moderate', 'high']
values = [135, 2088, 3607, 5393, 1539]
bars = plt.barh(labels, values)
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig('valid_confidence_level_distribution.pdf')
plt.show()

# %%
# check how many answers fall within the predefined confidence range
predefined_confidence_range = {
    'completely uncertain': (0, 4),
    'lowest': (5, 25),
    'low': (21, 49),
    'moderate': (60, 80),
    'high': (95, 100)
}

import numpy as np

df_conf_check = pd.read_csv('full_dataset.csv')
# add another column to the df_conf_check to indicate how many annotater_confidence_score fall within the predefined confidence range for each row
score_cols = [
    'annotater_confidence_score1',
    'annotater_confidence_score2',
    'annotater_confidence_score3',
    'annotater_confidence_score4',
    'annotater_confidence_score5'
]
df_conf_check['valid_confidence_score_count'] = 0
count_list = {
    'completely uncertain': 0,
    'lowest': 0,
    'low': 0,
    'moderate': 0,
    'high': 0
}

for index, row in df_conf_check.iterrows():
    confidence_range = predefined_confidence_range[row['llm_confidence_level']]
    valid_count = 0
    for col in score_cols:
        score = row[col]
        if confidence_range[0] <= score <= confidence_range[1]:
            valid_count += 1
            count_list[row['llm_confidence_level']] += 1
        else:
            df_conf_check.at[index, col] = np.nan
    df_conf_check.at[index, 'valid_confidence_score_count'] = valid_count

print(count_list)
print("total count: ", sum(count_list.values()))
# check the distribution of the valid_confidence_score_count
df_conf_check['valid_confidence_score_count'].value_counts()
df_conf_check
# Out:
# {'completely uncertain': 304, 'lowest': 2088, 'low': 3607, 'moderate': 5393, 'high': 1539}
# total count:  12931
#       orig_idx_in_40000_dataset  \
# 0                         18426
# 1                         23519
# 2                         32909
# 3                          3716
# 4                           611
# ...                         ...
# 9995                      37326
# 9996                      12866
# 9997                      20622
# 9998                      18055
# 9999                       9824
#
#                                                question  \
# 0     According to the Warcraft wiki, approximately ...
# 1     Which scientist received the Roebling Medal th...
# 2     What is the maximum depth of the Mediterranean...
# 3     What month, day, and year did Laura Toggs and ...
# 4     What day, month, and year was David Crombie ap...
# ...                                                 ...
# 9995  What venue did Ciara perform at on May 27, 201...
# 9996  What is the name and length of the 12th song o...
# 9997  What day, month, and year was David Crombie ap...
# 9998  Who were the seven countries that participated...
# 9999  What were the month, day, and year Anne Morgan...
#
#                                     ground_truth_answer  \
# 0                                                 13000
# 1                                         Linus Pauling
# 2                                                5109 m
# 3                                           May 10 2023
# 4                                           13 May 2004
# ...                                                 ...
# 9995                                     House of Blues
# 9996                            A Walk in Andante, 1:18
# 9997                                        13 May 2004
# 9998  Russia, Ukraine, Belarus, Poland. Italy, Germa...
# 9999                                    January 13 1559
#
#                                  uncertainty_expression llm_confidence_level  \
# 0     I think the Warcraft wiki says 13,000 years, b...                  low
# 1                     All signs point to Linus Pauling.             moderate
# 2     The Mediterranean Sea's maximum depth measures...                 high
# 3     To the best of my recollection, it was May 10,...             moderate
# 4     I believe it was 13 May 2004 when he received ...             moderate
# ...                                                 ...                  ...
# 9995  I suspect that Ciara performed at the House of...                  low
# 9996  If memory serves, "A Walk in Andante" is the 1...             moderate
# 9997  I'm not entirely sure, but my notes suggest 13...                  low
# 9998  Russia, Ukraine, Belarus, Poland, Italy, Germa...                 high
# 9999  It could be that Anne Morgan was styled Barone...                  low
#
#            source_llm  annotater_confidence_score1  \
# 0              GPT-4o                          NaN
# 1      Gemini-2.5 Pro                         73.0
# 2     Claude Sonnet 4                          NaN
# 3              Grok-3                          NaN
# 4              Grok-3                          NaN
# ...               ...                          ...
# 9995  Claude Sonnet 4                          NaN
# 9996           GPT-4o                         66.0
# 9997   Gemini-2.5 Pro                          NaN
# 9998           GPT-4o                          NaN
# 9999           Grok-3                          NaN
#
#       annotater_confidence_score2  annotater_confidence_score3  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                            71.0                          NaN
# ...                           ...                          ...
# 9995                          NaN                          NaN
# 9996                         80.0                         73.0
# 9997                          NaN                          NaN
# 9998                          NaN                          NaN
# 9999                          NaN                          NaN
#
#       annotater_confidence_score4  annotater_confidence_score5  \
# 0                             NaN                          NaN
# 1                            71.0                         62.0
# 2                             NaN                          NaN
# 3                            72.0                         68.0
# 4                            78.0                          NaN
# ...                           ...                          ...
# 9995                          NaN                          NaN
# 9996                         79.0                         69.0
# 9997                          NaN                         45.0
# 9998                          NaN                          NaN
# 9999                          NaN                          NaN
#
#       valid_confidence_score_count
# 0                                0
# 1                                3
# 2                                0
# 3                                2
# 4                                2
# ...                            ...
# 9995                             0
# 9996                             5
# 9997                             1
# 9998                             0
# 9999                             0
#
# [10000 rows x 12 columns]

# %%
df_conf_check[df_conf_check['valid_confidence_score_count']>=1]
# Out:
#       orig_idx_in_40000_dataset  \
# 1                         23519
# 3                          3716
# 4                           611
# 7                          8267
# 8                         29023
# ...                         ...
# 9984                       9269
# 9992                      33664
# 9993                      22549
# 9996                      12866
# 9997                      20622
#
#                                                question  \
# 1     Which scientist received the Roebling Medal th...
# 3     What month, day, and year did Laura Toggs and ...
# 4     What day, month, and year was David Crombie ap...
# 7     In which year was the municipality of Heliconi...
# 8     In what year did the Colombian mathematician J...
# ...                                                 ...
# 9984  Who finished 14th in the 2021–22 Premier Leagu...
# 9992  What nationality is the engineer who financed ...
# 9993  How many daughters did the mathematician Hsien...
# 9996  What is the name and length of the 12th song o...
# 9997  What day, month, and year was David Crombie ap...
#
#           ground_truth_answer  \
# 1               Linus Pauling
# 3                 May 10 2023
# 4                 13 May 2004
# 7                        1814
# 8                        1994
# ...                       ...
# 9984              Aston Villa
# 9992                  British
# 9993                        3
# 9996  A Walk in Andante, 1:18
# 9997              13 May 2004
#
#                                  uncertainty_expression  llm_confidence_level  \
# 1                     All signs point to Linus Pauling.              moderate
# 3     To the best of my recollection, it was May 10,...              moderate
# 4     I believe it was 13 May 2004 when he received ...              moderate
# 7     I’m fairly confident that the founding of Heli...              moderate
# 8                          My tentative answer is 1994.                   low
# ...                                                 ...                   ...
# 9984  I’m inclined to think that Aston Villa ended t...              moderate
# 9992                 The engineer was probably British.              moderate
# 9993  I searched my knowledge base but could not fin...  completely uncertain
# 9996  If memory serves, "A Walk in Andante" is the 1...              moderate
# 9997  I'm not entirely sure, but my notes suggest 13...                   low
#
#            source_llm  annotater_confidence_score1  \
# 1      Gemini-2.5 Pro                         73.0
# 3              Grok-3                          NaN
# 4              Grok-3                          NaN
# 7              Grok-3                         66.0
# 8      Gemini-2.5 Pro                         32.0
# ...               ...                          ...
# 9984           Grok-3                         71.0
# 9992  Claude Sonnet 4                          NaN
# 9993   Gemini-2.5 Pro                          NaN
# 9996           GPT-4o                         66.0
# 9997   Gemini-2.5 Pro                          NaN
#
#       annotater_confidence_score2  annotater_confidence_score3  \
# 1                             NaN                          NaN
# 3                             NaN                          NaN
# 4                            71.0                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# ...                           ...                          ...
# 9984                         63.0                         65.0
# 9992                         69.0                         75.0
# 9993                          NaN                          NaN
# 9996                         80.0                         73.0
# 9997                          NaN                          NaN
#
#       annotater_confidence_score4  annotater_confidence_score5  \
# 1                            71.0                         62.0
# 3                            72.0                         68.0
# 4                            78.0                          NaN
# 7                             NaN                          NaN
# 8                             NaN                         34.0
# ...                           ...                          ...
# 9984                          NaN                         63.0
# 9992                         64.0                         71.0
# 9993                          NaN                          3.0
# 9996                         79.0                         69.0
# 9997                          NaN                         45.0
#
#       valid_confidence_score_count
# 1                                3
# 3                                2
# 4                                2
# 7                                1
# 8                                2
# ...                            ...
# 9984                             4
# 9992                             4
# 9993                             1
# 9996                             5
# 9997                             1
#
# [7044 rows x 12 columns]

# %%
df_conf_check['llm_confidence_level'].value_counts()
# Out:
# llm_confidence_level
# low                     2375
# moderate                2375
# high                    2375
# lowest                  2375
# completely uncertain     500
# Name: count, dtype: int64

# %%
df_conf_check['valid_confidence_score_count'].value_counts()
# Out:
# valid_confidence_score_count
# 1    3298
# 0    2956
# 2    2124
# 3    1164
# 4     397
# 5      61
# Name: count, dtype: int64

# %%
df_conf_check['annotation_mean'] = df_conf_check[['annotater_confidence_score1', 'annotater_confidence_score2', 'annotater_confidence_score3', 'annotater_confidence_score4', 'annotater_confidence_score5']].mean(axis=1, skipna=True)

# %%
df_conf_check[df_conf_check['valid_confidence_score_count'] >= 1].to_csv('dataset_valid_confidence_score_count_1.csv', index=False)
df_conf_check[df_conf_check['valid_confidence_score_count'] >= 2].to_csv('dataset_valid_confidence_score_count_2.csv', index=False)
df_conf_check[df_conf_check['valid_confidence_score_count'] >= 3].to_csv('dataset_valid_confidence_score_count_3.csv', index=False)
df_conf_check[df_conf_check['valid_confidence_score_count'] >= 4].to_csv('dataset_valid_confidence_score_count_4.csv', index=False)
df_conf_check[df_conf_check['valid_confidence_score_count'] >= 5].to_csv('dataset_valid_confidence_score_count_5.csv', index=False)

# %%
test_df = pd.read_csv('dataset_valid_confidence_score_count_3.csv')
test_df['llm_confidence_level'].value_counts()
# Out:
# llm_confidence_level
# moderate                988
# low                     428
# lowest                  131
# high                     64
# completely uncertain     11
# Name: count, dtype: int64
